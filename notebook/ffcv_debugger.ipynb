# %%
import matplotlib.pyplot as plt
import torchvision.transforms as T
def show_image(image): 
    plt.figure()
    return plt.imshow(image.permute(1, 2, 0))

# %% [markdown]
# how does pytorch even work

# %%
from torchvision import datasets
from torchvision import transforms as T 
train_set = datasets.ImageFolder("/mnt/nfs/datasets/imagenet/train", transform = T.Compose([
    T.RandomResizedCrop((224, 224)), T.ToTensor()]))

# %%
train_set[1][0].shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# Testing awesome_ssl loading ffcv files

# %%
## load image dataset 
from hydra.utils import instantiate 
from hydra import initialize, compose
import importlib
from awesome_ssl.datasets import dataloader_utils
importlib.reload(dataloader_utils)
# Out:
# <module 'awesome_ssl.datasets.dataloader_utils' from '/mnt/nfs/home/yunxingl/self-supervised-learning/awesome_ssl/datasets/dataloader_utils.py'>

# %%
with initialize("../configs"): 
    config = compose("config.yaml", overrides=["+experiment=pretrain_byol"])

# %%
train, val, train_processor, val_processor = dataloader_utils.return_train_val_dataloaders(config)
# Out:
# 2
# my pipelines {'image': ('image', <ffcv.fields.rgb_image.RandomResizedCropRGBImageDecoder object at 0x7f09a4f2e880>, [<ffcv.transforms.ops.ToTensor object at 0x7f09a4f2e8b0>, <ffcv.transforms.ops.ToTorchImage object at 0x7f09a479fbb0>, <ffcv.transforms.ops.Convert object at 0x7f092ef021f0>, Normalize(mean=0, std=255), RandomHorizontalFlip(p=0.5), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]), 'image_g0': ('image', <ffcv.fields.rgb_image.RandomResizedCropRGBImageDecoder object at 0x7f09a4f2e880>, [<ffcv.transforms.ops.ToTensor object at 0x7f09a4f2e8b0>, <ffcv.transforms.ops.ToTorchImage object at 0x7f09a479fbb0>, <ffcv.transforms.ops.Convert object at 0x7f092ef021f0>, Normalize(mean=0, std=255), RandomApply(
#     p=0.3
#     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2])
# ), RandomGrayscale(p=0.2), RandomHorizontalFlip(p=0.5), RandomApply(
#     p=0.2
# ...

# %%
val_iter = iter(val)

# %%
arg_1, arg_2, arg_3, arg_4 = next(val_iter)
# Out:
# Exception ignored in: <finalize object at 0x7f09a6b044a0; dead>
# Traceback (most recent call last):
#   File "/mnt/nfs/home/yunxingl/.conda/envs/lucy_ffcv/lib/python3.9/weakref.py", line 591, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/mnt/nfs/home/yunxingl/.conda/envs/lucy_ffcv/lib/python3.9/site-packages/numba/core/dispatcher.py", line 312, in finalizer
#     for cres in overloads.values():
# KeyError: (array(uint8, 1d, C), array(uint8, 1d, C), uint32, uint32, uint32, uint32, Literal[int](0), Literal[int](0), Literal[int](1), Literal[int](1), Literal[bool](False), Literal[bool](False))
# Exception ignored in: <finalize object at 0x7f09a6a9b560; dead>
# Traceback (most recent call last):
#   File "/mnt/nfs/home/yunxingl/.conda/envs/lucy_ffcv/lib/python3.9/weakref.py", line 591, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
# ...

# %%
IMAGE_IDX = 6
show_image(arg_1[IMAGE_IDX])
show_image(arg_2[IMAGE_IDX])
show_image(arg_3[IMAGE_IDX])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
